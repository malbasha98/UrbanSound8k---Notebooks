# %% [markdown]
# Lokalno ucitavanje UrbanSound8k dataset-a:

# %%
# !wget https://zenodo.org/record/1203745/files/UrbanSound8K.tar.gz -O urban8k.tgz
# !tar -xzf urban8k.tgz
# !rm urban8k.tgz
# Out:
# --2023-06-03 15:32:58--  https://zenodo.org/record/1203745/files/UrbanSound8K.tar.gz
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6023741708 (5.6G) [application/octet-stream]
# Saving to: ‘urban8k.tgz’
#
# urban8k.tgz         100%[===================>]   5.61G  26.7MB/s    in 3m 39s
#
# 2023-06-03 15:36:39 (26.2 MB/s) - ‘urban8k.tgz’ saved [6023741708/6023741708]

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
directory_path = '/content/drive/MyDrive/UrbanSound Classification - Domaci/'

# %% [markdown]
# Podesavanja:

# %%
import os

root_folder=directory_path

MFCC_folder=os.path.join(root_folder,'MFCC')
if not os.path.exists(MFCC_folder):
    os.mkdir(MFCC_folder)

MFCC_vec_folder=os.path.join(root_folder,'MFCC_vec')
if not os.path.exists(MFCC_vec_folder):
    os.mkdir(MFCC_vec_folder)

Mel_folder=os.path.join(root_folder,'Mel')
if not os.path.exists(Mel_folder):
    os.mkdir(Mel_folder)

Mel_vec_folder=os.path.join(root_folder,'Mel_vec')
if not os.path.exists(Mel_vec_folder):
    os.mkdir(Mel_vec_folder)

for i in range(1,11):
    fold_folder_MFCC=os.path.join(MFCC_folder,'fold_'+str(i))
    if not os.path.exists(fold_folder_MFCC):
        os.mkdir(fold_folder_MFCC)
    fold_folder_Mel = os.path.join(Mel_folder, 'fold_' + str(i))
    if not os.path.exists(fold_folder_Mel):
        os.mkdir(fold_folder_Mel)
    fold_folder_MFCC_vec = os.path.join(MFCC_vec_folder, 'fold_' + str(i))
    if not os.path.exists(fold_folder_MFCC_vec):
        os.mkdir(fold_folder_MFCC_vec)
    fold_folder_Mel_vec = os.path.join(Mel_vec_folder, 'fold_' + str(i))
    if not os.path.exists(fold_folder_Mel_vec):
        os.mkdir(fold_folder_Mel_vec)

batch_size=32
init_lr = 1e-3
early_stopping_patience = 15
reduce_lr_patience = 8

#input_size=(1,13,344,1) # MFCC
input_size=(1,64,344,1) # Mel  
#input_size=(1,5,4,1) # MFCC - vec
#input_size=(1,8,8,1) # MFCC - vec

# %%
import pandas as pd
import numpy as np
pd.plotting.register_matplotlib_converters()
import random
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime

# %%
# Libraries for Classification and building Models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D, Dropout
from tensorflow.keras.utils import to_categorical 
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import tensorflow as tf

# %%
# Project Specific Libraries
import librosa
import librosa.display
import glob 
#import skimage

# %%
audio_path="UrbanSound8K/audio/"
metadata_path="UrbanSound8K/metadata/UrbanSound8K.csv"
df = pd.read_csv(metadata_path)

'''We will extract classes from this metadata.'''

df.head()
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
dat1, sampling_rate1 = librosa.load(audio_path+"fold5/100032-3-0-0.wav")
dat2, sampling_rate2 = librosa.load(audio_path+"fold5/100263-2-0-117.wav")

# %% [markdown]
# Pomocna klasa za preprocesiranje audio fajlova:

# %%
class AudioPrep:
    @staticmethod
    def open_audio_file(audio_file):
        sig, sr=librosa.load(audio_file, mono=False)
        return (sig, sr)
    @staticmethod
    def rechannel(aud, new_channel):
        sig, sr = aud
        if (sig.shape[0] == new_channel):
            # Nothing to do
            return aud
        if (new_channel == 1):
            # Convert from stereo to mono by selecting only the first channel
            resig=librosa.to_mono(sig)
        else:
            # Convert from mono to stereo by duplicating the first channel
            resig = librosa.util.stack([sig, sig])
        return ((resig, sr))
    @staticmethod
    def resample(aud, newsr):
        sig, sr = aud
        if (sr == newsr):
            # Nothing to do
            return aud
        num_channels = sig.shape[0]
        # Resample first channel
        if (num_channels > 1 and len(sig.shape)>1):
            # Resample the second channel and merge both channels
            reone = librosa.resample(y=sig[0,:],orig_sr= sr,target_sr= newsr)
            retwo = librosa.resample(y=sig[1,:],orig_sr= sr,target_sr= newsr,)
            resig = librosa.util.stack([reone, retwo])
        else:
            resig=librosa.resample(sig, orig_sr=sr, target_sr=newsr)
        return ((resig, newsr))
    @staticmethod
    def pad_trunc(aud, max_ms):
        sig, sr = aud
        sig_len=0
        if (len(sig.shape)>1):
            sig_len = sig.shape[1]
        else:
            sig_len=len(sig)
        max_len = sr//1000 * max_ms
        if (sig_len > max_len or sig_len < max_len):
            # Truncate the signal to the given length
            sig=librosa.util.fix_length(sig, size=max_len)
        return (sig, sr)
    @staticmethod
    def time_shift(aud, shift_limit):
        sig,sr = aud
        _, sig_len = sig.shape
        shift_amt = int(random.random() * shift_limit * sig_len)
        return (sig.roll(shift_amt), sr)
    @staticmethod
    def mel_spectrogram(aud, n_mels=64, n_fft=1024):
        sig,sr = aud
        top_db = 80
        spec=librosa.feature.melspectrogram(y=sig, sr=sr,n_mels=n_mels, n_fft=n_fft)
        spec=librosa.power_to_db(spec, ref=np.max)
        return spec
    @staticmethod
    def mel_spectrogram_vec(aud, n_mels=64, n_fft=1024):
        sig,sr = aud
        top_db = 80
        spec=np.mean(librosa.feature.melspectrogram(y=sig, sr=sr,n_mels=n_mels, n_fft=n_fft).T,axis=0)
        spec=librosa.power_to_db(spec, ref=np.max)
        return spec
    @staticmethod
    def mfccs(aud, n_mfcc=13):
        sig,sr = aud
        spec = librosa.feature.mfcc(y=sig, sr=sr, n_mfcc=n_mfcc)
        return spec
    @staticmethod
    def mfccs_vec(aud, n_mfcc=20):
        sig,sr = aud
        spec = np.mean(librosa.feature.mfcc(y=sig, sr=sr, n_mfcc=n_mfcc).T,axis=0)
        return spec

# %% [markdown]
# Pomocna klasa za ucitavanje feature-a audio fajlova:

# %%
class SoundDS:
    def __init__(self, df, data_path):
        self.df=df
        self.data_path=str(data_path)
        self.duration=4000
        self.sr=44100
        self.channel=1
        self.shift_pct=0.4
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        audio_file=self.data_path+ str(self.df["fold"][idx]) + '/' + self.df["slice_file_name"][idx]
        class_id=self.df["classID"][idx]
        aud=AudioPrep.open_audio_file(audio_file)
        rechan=AudioPrep.rechannel(aud,self.channel)
        reaud=AudioPrep.resample(rechan, self.sr)
        dur_aud=AudioPrep.pad_trunc(reaud, self.duration)
        feature = AudioPrep.mel_spectrogram(dur_aud,n_fft=1024)
        #feature=AudioPrep.mel_spectrogram(dur_aud)
        fold=self.df['fold'][idx]
        return feature, class_id, fold

# %% [markdown]
# Model:

# %%
from keras.callbacks import EarlyStopping
from keras.layers import Dense, Conv2D,  MaxPool2D, Flatten, GlobalAveragePooling2D,  BatchNormalization, Layer, Add
from keras.models import Sequential
from keras.models import Model
import tensorflow as tf

class ResnetBlock(Layer):
    """
    A standard resnet block.
    """

    def __init__(self, channels: int, down_sample=False):
        """
        channels: same as number of convolution kernels
        """
        super().__init__()

        self.__channels = channels
        self.__down_sample = down_sample
        self.__strides = [2, 1] if down_sample else [1, 1]

        KERNEL_SIZE = (3, 3)
        INIT_SCHEME = "he_normal"

        self.conv_1 = Conv2D(self.__channels, strides=self.__strides[0],
                             kernel_size=KERNEL_SIZE, padding="same", kernel_initializer=INIT_SCHEME)
        self.bn_1 = BatchNormalization()
        self.conv_2 = Conv2D(self.__channels, strides=self.__strides[1],
                             kernel_size=KERNEL_SIZE, padding="same", kernel_initializer=INIT_SCHEME)
        self.bn_2 = BatchNormalization()
        self.merge = Add()

        if self.__down_sample:
            # perform down sampling using stride of 2
            self.res_conv = Conv2D(
                self.__channels, strides=2, kernel_size=(1, 1), kernel_initializer=INIT_SCHEME, padding="same")
            self.res_bn = BatchNormalization()

    def call(self, inputs):
        res = inputs

        x = self.conv_1(inputs)
        x = self.bn_1(x)
        x = tf.nn.relu(x)
        x = self.conv_2(x)
        x = self.bn_2(x)

        if self.__down_sample:
            res = self.res_conv(res)
            res = self.res_bn(res)

        # if not perform down sample, then add a shortcut directly
        x = self.merge([x, res])
        out = tf.nn.relu(x)
        return out

class ResNet18(Model):

    def __init__(self, num_classes, **kwargs):
        """
            num_classes: number of classes in specific classification task.
        """
        super().__init__(**kwargs)
        self.conv_1 = Conv2D(64, (7, 7), strides=2,
                             padding="same", kernel_initializer="he_normal")
        self.init_bn = BatchNormalization()
        self.pool_2 = MaxPool2D(pool_size=(2, 2), strides=2, padding="same")
        self.res_1_1 = ResnetBlock(64)
        self.res_1_2 = ResnetBlock(64)
        self.res_2_1 = ResnetBlock(128, down_sample=True)
        self.res_2_2 = ResnetBlock(128)
        self.res_3_1 = ResnetBlock(256, down_sample=True)
        self.res_3_2 = ResnetBlock(256)
        self.res_4_1 = ResnetBlock(512, down_sample=True)
        self.res_4_2 = ResnetBlock(512)
        self.avg_pool = GlobalAveragePooling2D()
        self.flat = Flatten()
        self.fc = Dense(num_classes, activation="softmax")

    def call(self, inputs):
        out = self.conv_1(inputs)
        out = self.init_bn(out)
        out = tf.nn.relu(out)
        out = self.pool_2(out)
        for res_block in [self.res_1_1, self.res_1_2, self.res_2_1, self.res_2_2, self.res_3_1, self.res_3_2, self.res_4_1, self.res_4_2]:
            out = res_block(out)
        out = self.avg_pool(out)
        out = self.flat(out)
        out = self.fc(out)
        return out

def create_model():
    model = ResNet18(10)
    model.build(input_shape=input_size)
    return model

# %% [markdown]
# Ucitavanje podataka:

# %%
def load_data():
    metadata=pd.read_csv(metadata_path)
    audioDS=SoundDS(metadata, audio_path+"/fold")

    features=[]
    folds=[]
    labels=[]
    loaded_item_num=0
    for i in range(len(metadata)):
        feature, label, fold=audioDS.__getitem__(i)
        features.append(feature)
        labels.append(label)
        folds.append(fold)
        print("\r", loaded_item_num +i+1, "/8732", end="")
    print("\r\n")
    folds_np = np.array(folds)
    features_np = np.array(features)
    labels_np = np.array(labels)
    return features_np, labels_np, folds_np

print("\n-----Data preparation-----\n")
start = datetime.now()
features, labels, folds=load_data()
labels=to_categorical(labels)
duration = datetime.now() - start
print("\n-----Data ready for training (preparation time ", duration, ")-----\n")
# Out:
# -----Data preparation-----
#
#  8732 /8732
#
#
# -----Data ready for training (preparation time  0:04:21.720977 )-----

# %%
features.shape
# Out:
# (8732, 64, 344)

# %% [markdown]
# Treniranje:

# %%
########################################################################################################################
# START OF K-FOLD CROSS VALIDATION
########################################################################################################################

print(features.shape)
acc_per_fold=[]
loss_per_fold=[]
histories=[]
fold_idx=np.arange(1, 11)
for fold in fold_idx:
    test_X=features[np.where(folds==fold)]
    test_Y=labels[np.where(folds==fold)]
    train_X=features[np.where(folds!=fold)]
    train_Y=labels[np.where(folds!=fold)]

    if(len(train_X.shape)==3): # if audio files are mono
        test_X=tf.reshape(test_X, [test_X.shape[0], test_X.shape[1], test_X.shape[2],1])
        train_X=tf.reshape(train_X, [train_X.shape[0], train_X.shape[1], train_X.shape[2],1])

    model = create_model()
    model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss=tf.keras.losses.categorical_crossentropy,
                  metrics=[tf.keras.metrics.categorical_accuracy])
    
    path=Mel_folder+"/fold_"+str(fold)+"/"
    save_model = tf.keras.callbacks.ModelCheckpoint(path + "training_weights.h5",
                                                    monitor='val_categorical_accuracy', mode='max',
                                                    verbose=1, save_best_only=True,save_weights_only=True)

    csv_logger = tf.keras.callbacks.CSVLogger(path + 'training.csv')

    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_categorical_accuracy', mode='max', verbose=1,
                                                      patience=early_stopping_patience, restore_best_weights=True)

    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_categorical_accuracy', mode='max', verbose=1,
                                                     factor=0.1, patience=reduce_lr_patience)

    # Generate a print
    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold} ...')

    start = datetime.now()

    history = model.fit(train_X,train_Y,
                        batch_size = batch_size,
                        validation_data=(test_X, test_Y),
                        epochs=50,
                        callbacks=[save_model, csv_logger, early_stopping, reduce_lr])

    duration = datetime.now() - start

    histories.append(history)

    plt.clf()
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.savefig(path + "training_loss_plot"+str(fold)+".png")

    plt.clf()
    plt.plot(history.history['categorical_accuracy'])
    plt.plot(history.history['val_categorical_accuracy'])
    plt.savefig(path + "training_accuracy_plot"+str(fold)+".png")

    ########################################################################################################################
    # EVALUATE MODEL
    ########################################################################################################################

    scores = model.evaluate(test_X, test_Y, verbose=0)
    print(f'Score for fold {fold}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1] * 100}%')
    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])
# Out:
# (8732, 64, 344)
# WARNING:tensorflow:AutoGraph could not transform <bound method ResnetBlock.call of <__main__.ResnetBlock object at 0x7f37005cff70>> and will run it as-is.
# Cause: mangled names are not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method ResnetBlock.call of <__main__.ResnetBlock object at 0x7f37005cff70>> and will run it as-is.
# Cause: mangled names are not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/50
# 246/246 [==============================] - ETA: 0s - loss: 1.1576 - categorical_accuracy: 0.6155
# Epoch 1: val_categorical_accuracy improved from -inf to 0.44559, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_1/training_weights.h5
# 246/246 [==============================] - 33s 69ms/step - loss: 1.1576 - categorical_accuracy: 0.6155 - val_loss: 3.3315 - val_categorical_accuracy: 0.4456 - lr: 0.0010
# Epoch 2/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.5827 - categorical_accuracy: 0.8098
# Epoch 2: val_categorical_accuracy improved from 0.44559 to 0.48110, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_1/training_weights.h5
# 246/246 [==============================] - 16s 63ms/step - loss: 0.5817 - categorical_accuracy: 0.8103 - val_loss: 2.3556 - val_categorical_accuracy: 0.4811 - lr: 0.0010
# Epoch 3/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.4298 - categorical_accuracy: 0.8583
# Epoch 3: val_categorical_accuracy improved from 0.48110 to 0.53608, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_1/training_weights.h5
# 246/246 [==============================] - 16s 64ms/step - loss: 0.4298 - categorical_accuracy: 0.8580 - val_loss: 2.0546 - val_categorical_accuracy: 0.5361 - lr: 0.0010
# Epoch 4/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.3294 - categorical_accuracy: 0.8889
# Epoch 4: val_categorical_accuracy improved from 0.53608 to 0.54983, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_1/training_weights.h5
# 246/246 [==============================] - 16s 63ms/step - loss: 0.3301 - categorical_accuracy: 0.8885 - val_loss: 2.3655 - val_categorical_accuracy: 0.5498 - lr: 0.0010
# Epoch 5/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.2533 - categorical_accuracy: 0.9172
# Epoch 5: val_categorical_accuracy did not improve from 0.54983
# 246/246 [==============================] - 15s 60ms/step - loss: 0.2537 - categorical_accuracy: 0.9172 - val_loss: 2.6903 - val_categorical_accuracy: 0.4467 - lr: 0.0010
# Epoch 6/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.2054 - categorical_accuracy: 0.9307
# Epoch 6: val_categorical_accuracy did not improve from 0.54983
# 246/246 [==============================] - 15s 60ms/step - loss: 0.2054 - categorical_accuracy: 0.9308 - val_loss: 2.3327 - val_categorical_accuracy: 0.5407 - lr: 0.0010
# Epoch 7/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.1662 - categorical_accuracy: 0.9427
# Epoch 7: val_categorical_accuracy improved from 0.54983 to 0.65407, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_1/training_weights.h5
# 246/246 [==============================] - 16s 64ms/step - loss: 0.1667 - categorical_accuracy: 0.9426 - val_loss: 1.7951 - val_categorical_accuracy: 0.6541 - lr: 0.0010
# Epoch 8/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.1369 - categorical_accuracy: 0.9523
# Epoch 8: val_categorical_accuracy did not improve from 0.65407
# 246/246 [==============================] - 15s 60ms/step - loss: 0.1369 - categorical_accuracy: 0.9523 - val_loss: 3.9101 - val_categorical_accuracy: 0.4044 - lr: 0.0010
# Epoch 9/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.1224 - categorical_accuracy: 0.9570
# Epoch 9: val_categorical_accuracy did not improve from 0.65407
# 246/246 [==============================] - 15s 60ms/step - loss: 0.1221 - categorical_accuracy: 0.9571 - val_loss: 3.1100 - val_categorical_accuracy: 0.4971 - lr: 0.0010
# Epoch 10/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.1482 - categorical_accuracy: 0.9491
# Epoch 10: val_categorical_accuracy did not improve from 0.65407
# 246/246 [==============================] - 15s 61ms/step - loss: 0.1481 - categorical_accuracy: 0.9492 - val_loss: 2.5082 - val_categorical_accuracy: 0.6334 - lr: 0.0010
# Epoch 11/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.1122 - categorical_accuracy: 0.9624
# Epoch 11: val_categorical_accuracy did not improve from 0.65407
# 246/246 [==============================] - 15s 61ms/step - loss: 0.1123 - categorical_accuracy: 0.9623 - val_loss: 2.2145 - val_categorical_accuracy: 0.6140 - lr: 0.0010
# Epoch 12/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0881 - categorical_accuracy: 0.9707
# Epoch 12: val_categorical_accuracy did not improve from 0.65407
# 246/246 [==============================] - 15s 61ms/step - loss: 0.0883 - categorical_accuracy: 0.9705 - val_loss: 3.5185 - val_categorical_accuracy: 0.5155 - lr: 0.0010
# Epoch 13/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0776 - categorical_accuracy: 0.9732
# Epoch 13: val_categorical_accuracy did not improve from 0.65407
# 246/246 [==============================] - 15s 60ms/step - loss: 0.0776 - categorical_accuracy: 0.9732 - val_loss: 5.1038 - val_categorical_accuracy: 0.5281 - lr: 0.0010
# Epoch 14/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.1143 - categorical_accuracy: 0.9614
# Epoch 14: val_categorical_accuracy did not improve from 0.65407
# 246/246 [==============================] - 15s 60ms/step - loss: 0.1146 - categorical_accuracy: 0.9613 - val_loss: 2.8069 - val_categorical_accuracy: 0.5441 - lr: 0.0010
# Epoch 15/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0779 - categorical_accuracy: 0.9750
# Epoch 15: val_categorical_accuracy did not improve from 0.65407
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 246/246 [==============================] - 15s 60ms/step - loss: 0.0778 - categorical_accuracy: 0.9751 - val_loss: 2.4269 - val_categorical_accuracy: 0.6266 - lr: 0.0010
# Epoch 16/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0282 - categorical_accuracy: 0.9908
# Epoch 16: val_categorical_accuracy improved from 0.65407 to 0.66896, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_1/training_weights.h5
# 246/246 [==============================] - 16s 64ms/step - loss: 0.0281 - categorical_accuracy: 0.9908 - val_loss: 2.4491 - val_categorical_accuracy: 0.6690 - lr: 1.0000e-04
# Epoch 17/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0124 - categorical_accuracy: 0.9966
# Epoch 17: val_categorical_accuracy did not improve from 0.66896
# 246/246 [==============================] - 15s 60ms/step - loss: 0.0125 - categorical_accuracy: 0.9964 - val_loss: 2.6352 - val_categorical_accuracy: 0.6575 - lr: 1.0000e-04
# Epoch 18/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0097 - categorical_accuracy: 0.9971
# Epoch 18: val_categorical_accuracy did not improve from 0.66896
# 246/246 [==============================] - 15s 60ms/step - loss: 0.0097 - categorical_accuracy: 0.9971 - val_loss: 2.6629 - val_categorical_accuracy: 0.6644 - lr: 1.0000e-04
# Epoch 19/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0080 - categorical_accuracy: 0.9977
# Epoch 19: val_categorical_accuracy did not improve from 0.66896
# 246/246 [==============================] - 15s 60ms/step - loss: 0.0080 - categorical_accuracy: 0.9977 - val_loss: 2.8082 - val_categorical_accuracy: 0.6609 - lr: 1.0000e-04
# Epoch 20/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0075 - categorical_accuracy: 0.9983
# Epoch 20: val_categorical_accuracy did not improve from 0.66896
# 246/246 [==============================] - 15s 59ms/step - loss: 0.0075 - categorical_accuracy: 0.9983 - val_loss: 2.8235 - val_categorical_accuracy: 0.6598 - lr: 1.0000e-04
# Epoch 21/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0070 - categorical_accuracy: 0.9978
# Epoch 21: val_categorical_accuracy did not improve from 0.66896
# 246/246 [==============================] - 15s 60ms/step - loss: 0.0070 - categorical_accuracy: 0.9978 - val_loss: 2.8982 - val_categorical_accuracy: 0.6655 - lr: 1.0000e-04
# Epoch 22/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0059 - categorical_accuracy: 0.9982
# Epoch 22: val_categorical_accuracy did not improve from 0.66896
# 246/246 [==============================] - 15s 60ms/step - loss: 0.0058 - categorical_accuracy: 0.9982 - val_loss: 3.0422 - val_categorical_accuracy: 0.6575 - lr: 1.0000e-04
# Epoch 23/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0062 - categorical_accuracy: 0.9977
# Epoch 23: val_categorical_accuracy did not improve from 0.66896
# 246/246 [==============================] - 15s 60ms/step - loss: 0.0062 - categorical_accuracy: 0.9977 - val_loss: 2.9194 - val_categorical_accuracy: 0.6644 - lr: 1.0000e-04
# Epoch 24/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0053 - categorical_accuracy: 0.9982
# Epoch 24: val_categorical_accuracy did not improve from 0.66896
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 246/246 [==============================] - 15s 60ms/step - loss: 0.0053 - categorical_accuracy: 0.9982 - val_loss: 3.0091 - val_categorical_accuracy: 0.6575 - lr: 1.0000e-04
# Epoch 25/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0048 - categorical_accuracy: 0.9985
# Epoch 25: val_categorical_accuracy did not improve from 0.66896
# 246/246 [==============================] - 15s 60ms/step - loss: 0.0047 - categorical_accuracy: 0.9985 - val_loss: 3.0019 - val_categorical_accuracy: 0.6655 - lr: 1.0000e-05
# Epoch 26/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0044 - categorical_accuracy: 0.9985
# Epoch 26: val_categorical_accuracy did not improve from 0.66896
# 246/246 [==============================] - 15s 60ms/step - loss: 0.0044 - categorical_accuracy: 0.9985 - val_loss: 3.0226 - val_categorical_accuracy: 0.6655 - lr: 1.0000e-05
# Epoch 27/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0046 - categorical_accuracy: 0.9983
# Epoch 27: val_categorical_accuracy did not improve from 0.66896
# 246/246 [==============================] - 15s 60ms/step - loss: 0.0046 - categorical_accuracy: 0.9983 - val_loss: 3.0355 - val_categorical_accuracy: 0.6655 - lr: 1.0000e-05
# Epoch 28/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0038 - categorical_accuracy: 0.9989
# Epoch 28: val_categorical_accuracy did not improve from 0.66896
# 246/246 [==============================] - 15s 60ms/step - loss: 0.0038 - categorical_accuracy: 0.9989 - val_loss: 3.0330 - val_categorical_accuracy: 0.6667 - lr: 1.0000e-05
# Epoch 29/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0039 - categorical_accuracy: 0.9985
# Epoch 29: val_categorical_accuracy did not improve from 0.66896
# 246/246 [==============================] - 15s 60ms/step - loss: 0.0039 - categorical_accuracy: 0.9985 - val_loss: 3.0376 - val_categorical_accuracy: 0.6678 - lr: 1.0000e-05
# Epoch 30/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0041 - categorical_accuracy: 0.9986
# Epoch 30: val_categorical_accuracy did not improve from 0.66896
# 246/246 [==============================] - 15s 60ms/step - loss: 0.0041 - categorical_accuracy: 0.9986 - val_loss: 3.0962 - val_categorical_accuracy: 0.6632 - lr: 1.0000e-05
# Epoch 31/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0041 - categorical_accuracy: 0.9986
# Epoch 31: val_categorical_accuracy did not improve from 0.66896
# Restoring model weights from the end of the best epoch: 16.
# 246/246 [==============================] - 15s 61ms/step - loss: 0.0041 - categorical_accuracy: 0.9986 - val_loss: 3.0550 - val_categorical_accuracy: 0.6667 - lr: 1.0000e-05
# Epoch 31: early stopping
# Score for fold 1: loss of 2.4491024017333984; categorical_accuracy of 66.89575910568237%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/50
# 246/246 [==============================] - ETA: 0s - loss: 1.2085 - categorical_accuracy: 0.5926
# Epoch 1: val_categorical_accuracy improved from -inf to 0.35023, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_2/training_weights.h5
# 246/246 [==============================] - 31s 68ms/step - loss: 1.2085 - categorical_accuracy: 0.5926 - val_loss: 5.8496 - val_categorical_accuracy: 0.3502 - lr: 0.0010
# Epoch 2/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.7105 - categorical_accuracy: 0.7643
# Epoch 2: val_categorical_accuracy improved from 0.35023 to 0.52703, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_2/training_weights.h5
# 246/246 [==============================] - 16s 63ms/step - loss: 0.7106 - categorical_accuracy: 0.7640 - val_loss: 2.4741 - val_categorical_accuracy: 0.5270 - lr: 0.0010
# Epoch 3/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.4905 - categorical_accuracy: 0.8335
# Epoch 3: val_categorical_accuracy improved from 0.52703 to 0.58221, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_2/training_weights.h5
# 246/246 [==============================] - 16s 64ms/step - loss: 0.4907 - categorical_accuracy: 0.8334 - val_loss: 1.4437 - val_categorical_accuracy: 0.5822 - lr: 0.0010
# Epoch 4/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.3815 - categorical_accuracy: 0.8767
# Epoch 4: val_categorical_accuracy did not improve from 0.58221
# 246/246 [==============================] - 15s 61ms/step - loss: 0.3818 - categorical_accuracy: 0.8766 - val_loss: 3.2815 - val_categorical_accuracy: 0.4291 - lr: 0.0010
# Epoch 5/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.3084 - categorical_accuracy: 0.8983
# Epoch 5: val_categorical_accuracy did not improve from 0.58221
# 246/246 [==============================] - 15s 60ms/step - loss: 0.3082 - categorical_accuracy: 0.8984 - val_loss: 1.6898 - val_categorical_accuracy: 0.5439 - lr: 0.0010
# Epoch 6/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.2392 - categorical_accuracy: 0.9210
# Epoch 6: val_categorical_accuracy did not improve from 0.58221
# 246/246 [==============================] - 15s 60ms/step - loss: 0.2391 - categorical_accuracy: 0.9211 - val_loss: 2.4622 - val_categorical_accuracy: 0.5777 - lr: 0.0010
# Epoch 7/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.1971 - categorical_accuracy: 0.9348
# Epoch 7: val_categorical_accuracy improved from 0.58221 to 0.60586, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_2/training_weights.h5
# 246/246 [==============================] - 16s 64ms/step - loss: 0.1972 - categorical_accuracy: 0.9346 - val_loss: 2.0064 - val_categorical_accuracy: 0.6059 - lr: 0.0010
# Epoch 8/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.1753 - categorical_accuracy: 0.9431
# Epoch 8: val_categorical_accuracy did not improve from 0.60586
# 246/246 [==============================] - 15s 61ms/step - loss: 0.1753 - categorical_accuracy: 0.9431 - val_loss: 5.5896 - val_categorical_accuracy: 0.3446 - lr: 0.0010
# Epoch 9/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.1667 - categorical_accuracy: 0.9445
# Epoch 9: val_categorical_accuracy did not improve from 0.60586
# 246/246 [==============================] - 15s 61ms/step - loss: 0.1667 - categorical_accuracy: 0.9445 - val_loss: 3.2115 - val_categorical_accuracy: 0.5372 - lr: 0.0010
# Epoch 10/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.1358 - categorical_accuracy: 0.9550
# Epoch 10: val_categorical_accuracy did not improve from 0.60586
# 246/246 [==============================] - 15s 61ms/step - loss: 0.1363 - categorical_accuracy: 0.9549 - val_loss: 3.0519 - val_categorical_accuracy: 0.5518 - lr: 0.0010
# Epoch 11/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.1641 - categorical_accuracy: 0.9474
# Epoch 11: val_categorical_accuracy did not improve from 0.60586
# 246/246 [==============================] - 15s 60ms/step - loss: 0.1640 - categorical_accuracy: 0.9475 - val_loss: 2.9320 - val_categorical_accuracy: 0.4910 - lr: 0.0010
# Epoch 12/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0934 - categorical_accuracy: 0.9677
# Epoch 12: val_categorical_accuracy did not improve from 0.60586
# 246/246 [==============================] - 15s 61ms/step - loss: 0.0934 - categorical_accuracy: 0.9677 - val_loss: 2.6514 - val_categorical_accuracy: 0.5867 - lr: 0.0010
# Epoch 13/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0814 - categorical_accuracy: 0.9745
# Epoch 13: val_categorical_accuracy improved from 0.60586 to 0.62500, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_2/training_weights.h5
# 246/246 [==============================] - 16s 65ms/step - loss: 0.0816 - categorical_accuracy: 0.9744 - val_loss: 2.2523 - val_categorical_accuracy: 0.6250 - lr: 0.0010
# Epoch 14/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.1138 - categorical_accuracy: 0.9629
# Epoch 14: val_categorical_accuracy did not improve from 0.62500
# 246/246 [==============================] - 15s 61ms/step - loss: 0.1138 - categorical_accuracy: 0.9629 - val_loss: 3.2609 - val_categorical_accuracy: 0.5169 - lr: 0.0010
# Epoch 15/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0832 - categorical_accuracy: 0.9730
# Epoch 15: val_categorical_accuracy did not improve from 0.62500
# 246/246 [==============================] - 15s 61ms/step - loss: 0.0834 - categorical_accuracy: 0.9728 - val_loss: 2.7266 - val_categorical_accuracy: 0.5890 - lr: 0.0010
# Epoch 16/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0736 - categorical_accuracy: 0.9761
# Epoch 16: val_categorical_accuracy did not improve from 0.62500
# 246/246 [==============================] - 15s 61ms/step - loss: 0.0736 - categorical_accuracy: 0.9762 - val_loss: 2.7489 - val_categorical_accuracy: 0.5777 - lr: 0.0010
# Epoch 17/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0704 - categorical_accuracy: 0.9761
# Epoch 17: val_categorical_accuracy did not improve from 0.62500
# 246/246 [==============================] - 15s 60ms/step - loss: 0.0705 - categorical_accuracy: 0.9762 - val_loss: 2.4404 - val_categorical_accuracy: 0.5935 - lr: 0.0010
# Epoch 18/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0481 - categorical_accuracy: 0.9838
# Epoch 18: val_categorical_accuracy improved from 0.62500 to 0.64077, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_2/training_weights.h5
# 246/246 [==============================] - 16s 65ms/step - loss: 0.0481 - categorical_accuracy: 0.9838 - val_loss: 2.8834 - val_categorical_accuracy: 0.6408 - lr: 0.0010
# Epoch 19/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0697 - categorical_accuracy: 0.9783
# Epoch 19: val_categorical_accuracy did not improve from 0.64077
# 246/246 [==============================] - 15s 61ms/step - loss: 0.0701 - categorical_accuracy: 0.9781 - val_loss: 4.1777 - val_categorical_accuracy: 0.4437 - lr: 0.0010
# Epoch 20/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.1220 - categorical_accuracy: 0.9601
# Epoch 20: val_categorical_accuracy did not improve from 0.64077
# 246/246 [==============================] - 15s 62ms/step - loss: 0.1219 - categorical_accuracy: 0.9601 - val_loss: 2.8996 - val_categorical_accuracy: 0.5935 - lr: 0.0010
# Epoch 21/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0431 - categorical_accuracy: 0.9875
# Epoch 21: val_categorical_accuracy improved from 0.64077 to 0.70270, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_2/training_weights.h5
# 246/246 [==============================] - 16s 65ms/step - loss: 0.0431 - categorical_accuracy: 0.9875 - val_loss: 1.8334 - val_categorical_accuracy: 0.7027 - lr: 0.0010
# Epoch 22/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0193 - categorical_accuracy: 0.9943
# Epoch 22: val_categorical_accuracy did not improve from 0.70270
# 246/246 [==============================] - 15s 61ms/step - loss: 0.0192 - categorical_accuracy: 0.9943 - val_loss: 2.2341 - val_categorical_accuracy: 0.6340 - lr: 0.0010
# Epoch 23/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0427 - categorical_accuracy: 0.9858
# Epoch 23: val_categorical_accuracy did not improve from 0.70270
# 246/246 [==============================] - 15s 61ms/step - loss: 0.0429 - categorical_accuracy: 0.9857 - val_loss: 2.5934 - val_categorical_accuracy: 0.5766 - lr: 0.0010
# Epoch 24/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0836 - categorical_accuracy: 0.9719
# Epoch 24: val_categorical_accuracy did not improve from 0.70270
# 246/246 [==============================] - 15s 61ms/step - loss: 0.0835 - categorical_accuracy: 0.9720 - val_loss: 1.9059 - val_categorical_accuracy: 0.6858 - lr: 0.0010
# Epoch 25/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0400 - categorical_accuracy: 0.9872
# Epoch 25: val_categorical_accuracy did not improve from 0.70270
# 246/246 [==============================] - 15s 61ms/step - loss: 0.0400 - categorical_accuracy: 0.9873 - val_loss: 2.6149 - val_categorical_accuracy: 0.6633 - lr: 0.0010
# Epoch 26/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0434 - categorical_accuracy: 0.9865
# Epoch 26: val_categorical_accuracy did not improve from 0.70270
# 246/246 [==============================] - 15s 61ms/step - loss: 0.0434 - categorical_accuracy: 0.9865 - val_loss: 3.5127 - val_categorical_accuracy: 0.6577 - lr: 0.0010
# Epoch 27/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0564 - categorical_accuracy: 0.9841
# Epoch 27: val_categorical_accuracy did not improve from 0.70270
# 246/246 [==============================] - 15s 61ms/step - loss: 0.0564 - categorical_accuracy: 0.9841 - val_loss: 6.5098 - val_categorical_accuracy: 0.4628 - lr: 0.0010
# Epoch 28/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0235 - categorical_accuracy: 0.9927
# Epoch 28: val_categorical_accuracy did not improve from 0.70270
# 246/246 [==============================] - 15s 61ms/step - loss: 0.0236 - categorical_accuracy: 0.9927 - val_loss: 2.5603 - val_categorical_accuracy: 0.6667 - lr: 0.0010
# Epoch 29/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0238 - categorical_accuracy: 0.9930
# Epoch 29: val_categorical_accuracy did not improve from 0.70270
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 246/246 [==============================] - 15s 61ms/step - loss: 0.0240 - categorical_accuracy: 0.9929 - val_loss: 3.5080 - val_categorical_accuracy: 0.5349 - lr: 0.0010
# Epoch 30/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0110 - categorical_accuracy: 0.9958
# Epoch 30: val_categorical_accuracy did not improve from 0.70270
# 246/246 [==============================] - 15s 62ms/step - loss: 0.0110 - categorical_accuracy: 0.9958 - val_loss: 2.7405 - val_categorical_accuracy: 0.6813 - lr: 1.0000e-04
# Epoch 31/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0048 - categorical_accuracy: 0.9990
# Epoch 31: val_categorical_accuracy did not improve from 0.70270
# 246/246 [==============================] - 15s 61ms/step - loss: 0.0048 - categorical_accuracy: 0.9990 - val_loss: 2.7752 - val_categorical_accuracy: 0.6745 - lr: 1.0000e-04
# Epoch 32/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0039 - categorical_accuracy: 0.9991
# Epoch 32: val_categorical_accuracy did not improve from 0.70270
# 246/246 [==============================] - 15s 61ms/step - loss: 0.0039 - categorical_accuracy: 0.9991 - val_loss: 2.7751 - val_categorical_accuracy: 0.6700 - lr: 1.0000e-04
# Epoch 33/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0036 - categorical_accuracy: 0.9992
# Epoch 33: val_categorical_accuracy did not improve from 0.70270
# 246/246 [==============================] - 15s 61ms/step - loss: 0.0036 - categorical_accuracy: 0.9992 - val_loss: 2.8074 - val_categorical_accuracy: 0.6847 - lr: 1.0000e-04
# Epoch 34/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0031 - categorical_accuracy: 0.9994
# Epoch 34: val_categorical_accuracy did not improve from 0.70270
# 246/246 [==============================] - 15s 61ms/step - loss: 0.0031 - categorical_accuracy: 0.9994 - val_loss: 2.7613 - val_categorical_accuracy: 0.6813 - lr: 1.0000e-04
# Epoch 35/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0029 - categorical_accuracy: 0.9992
# Epoch 35: val_categorical_accuracy did not improve from 0.70270
# 246/246 [==============================] - 15s 61ms/step - loss: 0.0029 - categorical_accuracy: 0.9992 - val_loss: 2.8640 - val_categorical_accuracy: 0.6633 - lr: 1.0000e-04
# Epoch 36/50
# 245/246 [============================>.] - ETA: 0s - loss: 0.0032 - categorical_accuracy: 0.9986
# Epoch 36: val_categorical_accuracy did not improve from 0.70270
# Restoring model weights from the end of the best epoch: 21.
# 246/246 [==============================] - 15s 62ms/step - loss: 0.0032 - categorical_accuracy: 0.9986 - val_loss: 2.8510 - val_categorical_accuracy: 0.6430 - lr: 1.0000e-04
# Epoch 36: early stopping
# Score for fold 2: loss of 1.8333641290664673; categorical_accuracy of 70.27027010917664%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/50
# 244/244 [==============================] - ETA: 0s - loss: 1.1993 - categorical_accuracy: 0.6042
# Epoch 1: val_categorical_accuracy improved from -inf to 0.39459, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_3/training_weights.h5
# 244/244 [==============================] - 34s 73ms/step - loss: 1.1993 - categorical_accuracy: 0.6042 - val_loss: 4.3061 - val_categorical_accuracy: 0.3946 - lr: 0.0010
# Epoch 2/50
# 244/244 [==============================] - ETA: 0s - loss: 0.6484 - categorical_accuracy: 0.7860
# Epoch 2: val_categorical_accuracy improved from 0.39459 to 0.41622, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_3/training_weights.h5
# 244/244 [==============================] - 16s 66ms/step - loss: 0.6484 - categorical_accuracy: 0.7860 - val_loss: 3.2189 - val_categorical_accuracy: 0.4162 - lr: 0.0010
# Epoch 3/50
# 244/244 [==============================] - ETA: 0s - loss: 0.4578 - categorical_accuracy: 0.8527
# Epoch 3: val_categorical_accuracy improved from 0.41622 to 0.50811, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_3/training_weights.h5
# 244/244 [==============================] - 16s 67ms/step - loss: 0.4578 - categorical_accuracy: 0.8527 - val_loss: 2.5092 - val_categorical_accuracy: 0.5081 - lr: 0.0010
# Epoch 4/50
# 244/244 [==============================] - ETA: 0s - loss: 0.3536 - categorical_accuracy: 0.8840
# Epoch 4: val_categorical_accuracy did not improve from 0.50811
# 244/244 [==============================] - 15s 63ms/step - loss: 0.3536 - categorical_accuracy: 0.8840 - val_loss: 4.2839 - val_categorical_accuracy: 0.4097 - lr: 0.0010
# Epoch 5/50
# 244/244 [==============================] - ETA: 0s - loss: 0.2741 - categorical_accuracy: 0.9091
# Epoch 5: val_categorical_accuracy did not improve from 0.50811
# 244/244 [==============================] - 15s 62ms/step - loss: 0.2741 - categorical_accuracy: 0.9091 - val_loss: 3.9360 - val_categorical_accuracy: 0.4962 - lr: 0.0010
# Epoch 6/50
# 244/244 [==============================] - ETA: 0s - loss: 0.2112 - categorical_accuracy: 0.9262
# Epoch 6: val_categorical_accuracy improved from 0.50811 to 0.56541, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_3/training_weights.h5
# 244/244 [==============================] - 16s 67ms/step - loss: 0.2112 - categorical_accuracy: 0.9262 - val_loss: 2.8560 - val_categorical_accuracy: 0.5654 - lr: 0.0010
# Epoch 7/50
# 244/244 [==============================] - ETA: 0s - loss: 0.2041 - categorical_accuracy: 0.9316
# Epoch 7: val_categorical_accuracy did not improve from 0.56541
# 244/244 [==============================] - 15s 63ms/step - loss: 0.2041 - categorical_accuracy: 0.9316 - val_loss: 2.3786 - val_categorical_accuracy: 0.5168 - lr: 0.0010
# Epoch 8/50
# 244/244 [==============================] - ETA: 0s - loss: 0.1451 - categorical_accuracy: 0.9494
# Epoch 8: val_categorical_accuracy did not improve from 0.56541
# 244/244 [==============================] - 15s 63ms/step - loss: 0.1451 - categorical_accuracy: 0.9494 - val_loss: 3.3612 - val_categorical_accuracy: 0.5059 - lr: 0.0010
# Epoch 9/50
# 244/244 [==============================] - ETA: 0s - loss: 0.1651 - categorical_accuracy: 0.9467
# Epoch 9: val_categorical_accuracy did not improve from 0.56541
# 244/244 [==============================] - 15s 62ms/step - loss: 0.1651 - categorical_accuracy: 0.9467 - val_loss: 2.7701 - val_categorical_accuracy: 0.5308 - lr: 0.0010
# Epoch 10/50
# 244/244 [==============================] - ETA: 0s - loss: 0.1340 - categorical_accuracy: 0.9558
# Epoch 10: val_categorical_accuracy improved from 0.56541 to 0.57838, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_3/training_weights.h5
# 244/244 [==============================] - 17s 68ms/step - loss: 0.1340 - categorical_accuracy: 0.9558 - val_loss: 3.1793 - val_categorical_accuracy: 0.5784 - lr: 0.0010
# Epoch 11/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0994 - categorical_accuracy: 0.9653
# Epoch 11: val_categorical_accuracy did not improve from 0.57838
# 244/244 [==============================] - 15s 63ms/step - loss: 0.0994 - categorical_accuracy: 0.9653 - val_loss: 2.5387 - val_categorical_accuracy: 0.5492 - lr: 0.0010
# Epoch 12/50
# 244/244 [==============================] - ETA: 0s - loss: 0.1001 - categorical_accuracy: 0.9667
# Epoch 12: val_categorical_accuracy did not improve from 0.57838
# 244/244 [==============================] - 15s 63ms/step - loss: 0.1001 - categorical_accuracy: 0.9667 - val_loss: 3.5757 - val_categorical_accuracy: 0.5178 - lr: 0.0010
# Epoch 13/50
# 244/244 [==============================] - ETA: 0s - loss: 0.1044 - categorical_accuracy: 0.9625
# Epoch 13: val_categorical_accuracy did not improve from 0.57838
# 244/244 [==============================] - 15s 63ms/step - loss: 0.1044 - categorical_accuracy: 0.9625 - val_loss: 3.7311 - val_categorical_accuracy: 0.5297 - lr: 0.0010
# Epoch 14/50
# 244/244 [==============================] - ETA: 0s - loss: 0.1029 - categorical_accuracy: 0.9667
# Epoch 14: val_categorical_accuracy did not improve from 0.57838
# 244/244 [==============================] - 15s 63ms/step - loss: 0.1029 - categorical_accuracy: 0.9667 - val_loss: 3.0704 - val_categorical_accuracy: 0.5503 - lr: 0.0010
# Epoch 15/50
# 244/244 [==============================] - ETA: 0s - loss: 0.1232 - categorical_accuracy: 0.9588
# Epoch 15: val_categorical_accuracy did not improve from 0.57838
# 244/244 [==============================] - 15s 63ms/step - loss: 0.1232 - categorical_accuracy: 0.9588 - val_loss: 4.4158 - val_categorical_accuracy: 0.5005 - lr: 0.0010
# Epoch 16/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0541 - categorical_accuracy: 0.9805
# Epoch 16: val_categorical_accuracy improved from 0.57838 to 0.58162, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_3/training_weights.h5
# 244/244 [==============================] - 16s 67ms/step - loss: 0.0541 - categorical_accuracy: 0.9805 - val_loss: 3.0914 - val_categorical_accuracy: 0.5816 - lr: 0.0010
# Epoch 17/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0540 - categorical_accuracy: 0.9812
# Epoch 17: val_categorical_accuracy did not improve from 0.58162
# 244/244 [==============================] - 15s 63ms/step - loss: 0.0540 - categorical_accuracy: 0.9812 - val_loss: 4.4036 - val_categorical_accuracy: 0.4551 - lr: 0.0010
# Epoch 18/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0845 - categorical_accuracy: 0.9737
# Epoch 18: val_categorical_accuracy did not improve from 0.58162
# 244/244 [==============================] - 15s 63ms/step - loss: 0.0845 - categorical_accuracy: 0.9737 - val_loss: 7.8345 - val_categorical_accuracy: 0.4086 - lr: 0.0010
# Epoch 19/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0780 - categorical_accuracy: 0.9746
# Epoch 19: val_categorical_accuracy did not improve from 0.58162
# 244/244 [==============================] - 15s 63ms/step - loss: 0.0780 - categorical_accuracy: 0.9746 - val_loss: 3.3033 - val_categorical_accuracy: 0.5708 - lr: 0.0010
# Epoch 20/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0465 - categorical_accuracy: 0.9840
# Epoch 20: val_categorical_accuracy did not improve from 0.58162
# 244/244 [==============================] - 15s 62ms/step - loss: 0.0465 - categorical_accuracy: 0.9840 - val_loss: 2.6052 - val_categorical_accuracy: 0.5795 - lr: 0.0010
# Epoch 21/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0436 - categorical_accuracy: 0.9857
# Epoch 21: val_categorical_accuracy improved from 0.58162 to 0.60216, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_3/training_weights.h5
# 244/244 [==============================] - 16s 65ms/step - loss: 0.0436 - categorical_accuracy: 0.9857 - val_loss: 2.8428 - val_categorical_accuracy: 0.6022 - lr: 0.0010
# Epoch 22/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0563 - categorical_accuracy: 0.9804
# Epoch 22: val_categorical_accuracy did not improve from 0.60216
# 244/244 [==============================] - 15s 61ms/step - loss: 0.0563 - categorical_accuracy: 0.9804 - val_loss: 3.5669 - val_categorical_accuracy: 0.5719 - lr: 0.0010
# Epoch 23/50
# 244/244 [==============================] - ETA: 0s - loss: 0.1110 - categorical_accuracy: 0.9666
# Epoch 23: val_categorical_accuracy did not improve from 0.60216
# 244/244 [==============================] - 15s 62ms/step - loss: 0.1110 - categorical_accuracy: 0.9666 - val_loss: 2.7792 - val_categorical_accuracy: 0.5795 - lr: 0.0010
# Epoch 24/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0548 - categorical_accuracy: 0.9840
# Epoch 24: val_categorical_accuracy did not improve from 0.60216
# 244/244 [==============================] - 15s 62ms/step - loss: 0.0548 - categorical_accuracy: 0.9840 - val_loss: 3.8956 - val_categorical_accuracy: 0.4746 - lr: 0.0010
# Epoch 25/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0460 - categorical_accuracy: 0.9845
# Epoch 25: val_categorical_accuracy did not improve from 0.60216
# 244/244 [==============================] - 15s 62ms/step - loss: 0.0460 - categorical_accuracy: 0.9845 - val_loss: 3.0919 - val_categorical_accuracy: 0.5816 - lr: 0.0010
# Epoch 26/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0196 - categorical_accuracy: 0.9928
# Epoch 26: val_categorical_accuracy did not improve from 0.60216
# 244/244 [==============================] - 15s 62ms/step - loss: 0.0196 - categorical_accuracy: 0.9928 - val_loss: 3.3046 - val_categorical_accuracy: 0.5676 - lr: 0.0010
# Epoch 27/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0479 - categorical_accuracy: 0.9830
# Epoch 27: val_categorical_accuracy did not improve from 0.60216
# 244/244 [==============================] - 15s 61ms/step - loss: 0.0479 - categorical_accuracy: 0.9830 - val_loss: 3.1170 - val_categorical_accuracy: 0.5881 - lr: 0.0010
# Epoch 28/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0440 - categorical_accuracy: 0.9860
# Epoch 28: val_categorical_accuracy did not improve from 0.60216
# 244/244 [==============================] - 15s 61ms/step - loss: 0.0440 - categorical_accuracy: 0.9860 - val_loss: 2.7756 - val_categorical_accuracy: 0.5741 - lr: 0.0010
# Epoch 29/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0360 - categorical_accuracy: 0.9874
# Epoch 29: val_categorical_accuracy did not improve from 0.60216
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 244/244 [==============================] - 15s 61ms/step - loss: 0.0360 - categorical_accuracy: 0.9874 - val_loss: 4.4073 - val_categorical_accuracy: 0.5762 - lr: 0.0010
# Epoch 30/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0257 - categorical_accuracy: 0.9908
# Epoch 30: val_categorical_accuracy improved from 0.60216 to 0.61946, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_3/training_weights.h5
# 244/244 [==============================] - 16s 65ms/step - loss: 0.0257 - categorical_accuracy: 0.9908 - val_loss: 2.3360 - val_categorical_accuracy: 0.6195 - lr: 1.0000e-04
# Epoch 31/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0106 - categorical_accuracy: 0.9971
# Epoch 31: val_categorical_accuracy did not improve from 0.61946
# 244/244 [==============================] - 15s 62ms/step - loss: 0.0106 - categorical_accuracy: 0.9971 - val_loss: 2.3986 - val_categorical_accuracy: 0.6065 - lr: 1.0000e-04
# Epoch 32/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0074 - categorical_accuracy: 0.9978
# Epoch 32: val_categorical_accuracy did not improve from 0.61946
# 244/244 [==============================] - 15s 61ms/step - loss: 0.0074 - categorical_accuracy: 0.9978 - val_loss: 2.4138 - val_categorical_accuracy: 0.6141 - lr: 1.0000e-04
# Epoch 33/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0067 - categorical_accuracy: 0.9978
# Epoch 33: val_categorical_accuracy did not improve from 0.61946
# 244/244 [==============================] - 15s 61ms/step - loss: 0.0067 - categorical_accuracy: 0.9978 - val_loss: 2.4233 - val_categorical_accuracy: 0.6130 - lr: 1.0000e-04
# Epoch 34/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0058 - categorical_accuracy: 0.9985
# Epoch 34: val_categorical_accuracy did not improve from 0.61946
# 244/244 [==============================] - 15s 62ms/step - loss: 0.0058 - categorical_accuracy: 0.9985 - val_loss: 2.4822 - val_categorical_accuracy: 0.6086 - lr: 1.0000e-04
# Epoch 35/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0060 - categorical_accuracy: 0.9977
# Epoch 35: val_categorical_accuracy did not improve from 0.61946
# 244/244 [==============================] - 15s 62ms/step - loss: 0.0060 - categorical_accuracy: 0.9977 - val_loss: 2.6619 - val_categorical_accuracy: 0.6032 - lr: 1.0000e-04
# Epoch 36/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0060 - categorical_accuracy: 0.9977
# Epoch 36: val_categorical_accuracy did not improve from 0.61946
# 244/244 [==============================] - 15s 61ms/step - loss: 0.0060 - categorical_accuracy: 0.9977 - val_loss: 2.7946 - val_categorical_accuracy: 0.5924 - lr: 1.0000e-04
# Epoch 37/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0052 - categorical_accuracy: 0.9985
# Epoch 37: val_categorical_accuracy did not improve from 0.61946
# 244/244 [==============================] - 15s 61ms/step - loss: 0.0052 - categorical_accuracy: 0.9985 - val_loss: 2.8551 - val_categorical_accuracy: 0.5935 - lr: 1.0000e-04
# Epoch 38/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0053 - categorical_accuracy: 0.9983
# Epoch 38: val_categorical_accuracy did not improve from 0.61946
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 244/244 [==============================] - 15s 61ms/step - loss: 0.0053 - categorical_accuracy: 0.9983 - val_loss: 2.6244 - val_categorical_accuracy: 0.6065 - lr: 1.0000e-04
# Epoch 39/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0041 - categorical_accuracy: 0.9986
# Epoch 39: val_categorical_accuracy did not improve from 0.61946
# 244/244 [==============================] - 15s 61ms/step - loss: 0.0041 - categorical_accuracy: 0.9986 - val_loss: 2.7112 - val_categorical_accuracy: 0.5924 - lr: 1.0000e-05
# Epoch 40/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0042 - categorical_accuracy: 0.9988
# Epoch 40: val_categorical_accuracy did not improve from 0.61946
# 244/244 [==============================] - 15s 61ms/step - loss: 0.0042 - categorical_accuracy: 0.9988 - val_loss: 2.7538 - val_categorical_accuracy: 0.5946 - lr: 1.0000e-05
# Epoch 41/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0043 - categorical_accuracy: 0.9983
# Epoch 41: val_categorical_accuracy did not improve from 0.61946
# 244/244 [==============================] - 15s 61ms/step - loss: 0.0043 - categorical_accuracy: 0.9983 - val_loss: 2.7471 - val_categorical_accuracy: 0.5924 - lr: 1.0000e-05
# Epoch 42/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0037 - categorical_accuracy: 0.9988
# Epoch 42: val_categorical_accuracy did not improve from 0.61946
# 244/244 [==============================] - 15s 61ms/step - loss: 0.0037 - categorical_accuracy: 0.9988 - val_loss: 2.7356 - val_categorical_accuracy: 0.5903 - lr: 1.0000e-05
# Epoch 43/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0041 - categorical_accuracy: 0.9986
# Epoch 43: val_categorical_accuracy did not improve from 0.61946
# 244/244 [==============================] - 15s 61ms/step - loss: 0.0041 - categorical_accuracy: 0.9986 - val_loss: 2.7720 - val_categorical_accuracy: 0.5946 - lr: 1.0000e-05
# Epoch 44/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0036 - categorical_accuracy: 0.9990
# Epoch 44: val_categorical_accuracy did not improve from 0.61946
# 244/244 [==============================] - 15s 62ms/step - loss: 0.0036 - categorical_accuracy: 0.9990 - val_loss: 2.7631 - val_categorical_accuracy: 0.5903 - lr: 1.0000e-05
# Epoch 45/50
# 244/244 [==============================] - ETA: 0s - loss: 0.0038 - categorical_accuracy: 0.9987
# Epoch 45: val_categorical_accuracy did not improve from 0.61946
# Restoring model weights from the end of the best epoch: 30.
# 244/244 [==============================] - 15s 61ms/step - loss: 0.0038 - categorical_accuracy: 0.9987 - val_loss: 2.7803 - val_categorical_accuracy: 0.5957 - lr: 1.0000e-05
# Epoch 45: early stopping
# Score for fold 3: loss of 2.335982322692871; categorical_accuracy of 61.945945024490356%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/50
# 242/242 [==============================] - ETA: 0s - loss: 1.1443 - categorical_accuracy: 0.6175
# Epoch 1: val_categorical_accuracy improved from -inf to 0.32323, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_4/training_weights.h5
# 242/242 [==============================] - 31s 69ms/step - loss: 1.1443 - categorical_accuracy: 0.6175 - val_loss: 5.0683 - val_categorical_accuracy: 0.3232 - lr: 0.0010
# Epoch 2/50
# 242/242 [==============================] - ETA: 0s - loss: 0.6479 - categorical_accuracy: 0.7888
# Epoch 2: val_categorical_accuracy improved from 0.32323 to 0.64747, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_4/training_weights.h5
# 242/242 [==============================] - 16s 65ms/step - loss: 0.6479 - categorical_accuracy: 0.7888 - val_loss: 1.4417 - val_categorical_accuracy: 0.6475 - lr: 0.0010
# Epoch 3/50
# 242/242 [==============================] - ETA: 0s - loss: 0.4473 - categorical_accuracy: 0.8512
# Epoch 3: val_categorical_accuracy did not improve from 0.64747
# 242/242 [==============================] - 15s 61ms/step - loss: 0.4473 - categorical_accuracy: 0.8512 - val_loss: 3.8392 - val_categorical_accuracy: 0.3899 - lr: 0.0010
# Epoch 4/50
# 242/242 [==============================] - ETA: 0s - loss: 0.3663 - categorical_accuracy: 0.8735
# Epoch 4: val_categorical_accuracy did not improve from 0.64747
# 242/242 [==============================] - 15s 61ms/step - loss: 0.3663 - categorical_accuracy: 0.8735 - val_loss: 2.4826 - val_categorical_accuracy: 0.5040 - lr: 0.0010
# Epoch 5/50
# 242/242 [==============================] - ETA: 0s - loss: 0.2673 - categorical_accuracy: 0.9089
# Epoch 5: val_categorical_accuracy did not improve from 0.64747
# 242/242 [==============================] - 15s 61ms/step - loss: 0.2673 - categorical_accuracy: 0.9089 - val_loss: 3.6994 - val_categorical_accuracy: 0.3899 - lr: 0.0010
# Epoch 6/50
# 242/242 [==============================] - ETA: 0s - loss: 0.2210 - categorical_accuracy: 0.9231
# Epoch 6: val_categorical_accuracy did not improve from 0.64747
# 242/242 [==============================] - 15s 61ms/step - loss: 0.2210 - categorical_accuracy: 0.9231 - val_loss: 1.6317 - val_categorical_accuracy: 0.6444 - lr: 0.0010
# Epoch 7/50
# 242/242 [==============================] - ETA: 0s - loss: 0.1845 - categorical_accuracy: 0.9381
# Epoch 7: val_categorical_accuracy did not improve from 0.64747
# 242/242 [==============================] - 15s 61ms/step - loss: 0.1845 - categorical_accuracy: 0.9381 - val_loss: 1.9027 - val_categorical_accuracy: 0.5919 - lr: 0.0010
# Epoch 8/50
# 242/242 [==============================] - ETA: 0s - loss: 0.1555 - categorical_accuracy: 0.9491
# Epoch 8: val_categorical_accuracy did not improve from 0.64747
# 242/242 [==============================] - 15s 62ms/step - loss: 0.1555 - categorical_accuracy: 0.9491 - val_loss: 2.6527 - val_categorical_accuracy: 0.5808 - lr: 0.0010
# Epoch 9/50
# 242/242 [==============================] - ETA: 0s - loss: 0.1370 - categorical_accuracy: 0.9536
# Epoch 9: val_categorical_accuracy did not improve from 0.64747
# 242/242 [==============================] - 15s 61ms/step - loss: 0.1370 - categorical_accuracy: 0.9536 - val_loss: 2.1200 - val_categorical_accuracy: 0.6121 - lr: 0.0010
# Epoch 10/50
# 242/242 [==============================] - ETA: 0s - loss: 0.1230 - categorical_accuracy: 0.9583
# Epoch 10: val_categorical_accuracy did not improve from 0.64747
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 242/242 [==============================] - 15s 62ms/step - loss: 0.1230 - categorical_accuracy: 0.9583 - val_loss: 2.8048 - val_categorical_accuracy: 0.5384 - lr: 0.0010
# Epoch 11/50
# 242/242 [==============================] - ETA: 0s - loss: 0.0496 - categorical_accuracy: 0.9830
# Epoch 11: val_categorical_accuracy improved from 0.64747 to 0.68889, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_4/training_weights.h5
# 242/242 [==============================] - 16s 66ms/step - loss: 0.0496 - categorical_accuracy: 0.9830 - val_loss: 1.5559 - val_categorical_accuracy: 0.6889 - lr: 1.0000e-04
# Epoch 12/50
# 242/242 [==============================] - ETA: 0s - loss: 0.0313 - categorical_accuracy: 0.9907
# Epoch 12: val_categorical_accuracy did not improve from 0.68889
# 242/242 [==============================] - 15s 62ms/step - loss: 0.0313 - categorical_accuracy: 0.9907 - val_loss: 1.6252 - val_categorical_accuracy: 0.6818 - lr: 1.0000e-04
# Epoch 13/50
# 242/242 [==============================] - ETA: 0s - loss: 0.0216 - categorical_accuracy: 0.9942
# Epoch 13: val_categorical_accuracy did not improve from 0.68889
# 242/242 [==============================] - 15s 61ms/step - loss: 0.0216 - categorical_accuracy: 0.9942 - val_loss: 1.6716 - val_categorical_accuracy: 0.6859 - lr: 1.0000e-04
# Epoch 14/50
# 242/242 [==============================] - ETA: 0s - loss: 0.0197 - categorical_accuracy: 0.9947
# Epoch 14: val_categorical_accuracy improved from 0.68889 to 0.69091, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_4/training_weights.h5
# ...
# Epoch 37/50
# 247/248 [============================>.] - ETA: 0s - loss: 0.0031 - categorical_accuracy: 0.9990
# Epoch 37: val_categorical_accuracy did not improve from 0.77083
# 248/248 [==============================] - 15s 62ms/step - loss: 0.0033 - categorical_accuracy: 0.9989 - val_loss: 1.8596 - val_categorical_accuracy: 0.7512 - lr: 1.0000e-05
# Epoch 38/50
# 247/248 [============================>.] - ETA: 0s - loss: 0.0035 - categorical_accuracy: 0.9985
# Epoch 38: val_categorical_accuracy did not improve from 0.77083
# 248/248 [==============================] - 15s 62ms/step - loss: 0.0035 - categorical_accuracy: 0.9985 - val_loss: 1.8507 - val_categorical_accuracy: 0.7586 - lr: 1.0000e-05
# Epoch 39/50
# 247/248 [============================>.] - ETA: 0s - loss: 0.0033 - categorical_accuracy: 0.9986
# Epoch 39: val_categorical_accuracy did not improve from 0.77083
# 248/248 [==============================] - 15s 62ms/step - loss: 0.0032 - categorical_accuracy: 0.9986 - val_loss: 1.8445 - val_categorical_accuracy: 0.7561 - lr: 1.0000e-05
# Epoch 40/50
# 247/248 [============================>.] - ETA: 0s - loss: 0.0035 - categorical_accuracy: 0.9986
# Epoch 40: val_categorical_accuracy did not improve from 0.77083
# Restoring model weights from the end of the best epoch: 25.
# 248/248 [==============================] - 15s 62ms/step - loss: 0.0035 - categorical_accuracy: 0.9986 - val_loss: 1.8659 - val_categorical_accuracy: 0.7561 - lr: 1.0000e-05
# Epoch 40: early stopping
# Score for fold 9: loss of 1.7323498725891113; categorical_accuracy of 77.08333134651184%
# ------------------------------------------------------------------------
# Training for fold 10 ...
# Epoch 1/50
# 247/247 [==============================] - ETA: 0s - loss: 1.2098 - categorical_accuracy: 0.5940
# Epoch 1: val_categorical_accuracy improved from -inf to 0.21386, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_10/training_weights.h5
# 247/247 [==============================] - 31s 68ms/step - loss: 1.2098 - categorical_accuracy: 0.5940 - val_loss: 7.8263 - val_categorical_accuracy: 0.2139 - lr: 0.0010
# Epoch 2/50
# 247/247 [==============================] - ETA: 0s - loss: 0.6651 - categorical_accuracy: 0.7762
# Epoch 2: val_categorical_accuracy improved from 0.21386 to 0.54002, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_10/training_weights.h5
# 247/247 [==============================] - 16s 65ms/step - loss: 0.6651 - categorical_accuracy: 0.7762 - val_loss: 2.3673 - val_categorical_accuracy: 0.5400 - lr: 0.0010
# Epoch 3/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.4737 - categorical_accuracy: 0.8390
# Epoch 3: val_categorical_accuracy improved from 0.54002 to 0.65233, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_10/training_weights.h5
# 247/247 [==============================] - 16s 66ms/step - loss: 0.4739 - categorical_accuracy: 0.8391 - val_loss: 1.6640 - val_categorical_accuracy: 0.6523 - lr: 0.0010
# Epoch 4/50
# 247/247 [==============================] - ETA: 0s - loss: 0.3810 - categorical_accuracy: 0.8721
# Epoch 4: val_categorical_accuracy did not improve from 0.65233
# 247/247 [==============================] - 15s 62ms/step - loss: 0.3810 - categorical_accuracy: 0.8721 - val_loss: 4.8208 - val_categorical_accuracy: 0.3716 - lr: 0.0010
# Epoch 5/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.2592 - categorical_accuracy: 0.9148
# Epoch 5: val_categorical_accuracy improved from 0.65233 to 0.66547, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_10/training_weights.h5
# 247/247 [==============================] - 17s 70ms/step - loss: 0.2592 - categorical_accuracy: 0.9146 - val_loss: 1.5821 - val_categorical_accuracy: 0.6655 - lr: 0.0010
# Epoch 6/50
# 247/247 [==============================] - ETA: 0s - loss: 0.2305 - categorical_accuracy: 0.9191
# Epoch 6: val_categorical_accuracy did not improve from 0.66547
# 247/247 [==============================] - 15s 61ms/step - loss: 0.2305 - categorical_accuracy: 0.9191 - val_loss: 2.0195 - val_categorical_accuracy: 0.6440 - lr: 0.0010
# Epoch 7/50
# 247/247 [==============================] - ETA: 0s - loss: 0.2102 - categorical_accuracy: 0.9293
# Epoch 7: val_categorical_accuracy did not improve from 0.66547
# 247/247 [==============================] - 15s 62ms/step - loss: 0.2102 - categorical_accuracy: 0.9293 - val_loss: 2.5203 - val_categorical_accuracy: 0.5878 - lr: 0.0010
# Epoch 8/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.1708 - categorical_accuracy: 0.9403
# Epoch 8: val_categorical_accuracy did not improve from 0.66547
# 247/247 [==============================] - 15s 62ms/step - loss: 0.1713 - categorical_accuracy: 0.9401 - val_loss: 2.0099 - val_categorical_accuracy: 0.6368 - lr: 0.0010
# Epoch 9/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.1683 - categorical_accuracy: 0.9432
# Epoch 9: val_categorical_accuracy did not improve from 0.66547
# 247/247 [==============================] - 15s 62ms/step - loss: 0.1685 - categorical_accuracy: 0.9430 - val_loss: 5.8349 - val_categorical_accuracy: 0.3011 - lr: 0.0010
# Epoch 10/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.1334 - categorical_accuracy: 0.9517
# Epoch 10: val_categorical_accuracy did not improve from 0.66547
# 247/247 [==============================] - 15s 62ms/step - loss: 0.1340 - categorical_accuracy: 0.9516 - val_loss: 4.0375 - val_categorical_accuracy: 0.4373 - lr: 0.0010
# Epoch 11/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.1428 - categorical_accuracy: 0.9525
# Epoch 11: val_categorical_accuracy improved from 0.66547 to 0.66667, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_10/training_weights.h5
# 247/247 [==============================] - 16s 65ms/step - loss: 0.1432 - categorical_accuracy: 0.9524 - val_loss: 1.5325 - val_categorical_accuracy: 0.6667 - lr: 0.0010
# Epoch 12/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.1106 - categorical_accuracy: 0.9623
# Epoch 12: val_categorical_accuracy did not improve from 0.66667
# 247/247 [==============================] - 15s 62ms/step - loss: 0.1105 - categorical_accuracy: 0.9623 - val_loss: 2.3648 - val_categorical_accuracy: 0.6189 - lr: 0.0010
# Epoch 13/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0679 - categorical_accuracy: 0.9751
# Epoch 13: val_categorical_accuracy did not improve from 0.66667
# 247/247 [==============================] - 15s 61ms/step - loss: 0.0680 - categorical_accuracy: 0.9750 - val_loss: 1.6681 - val_categorical_accuracy: 0.6452 - lr: 0.0010
# Epoch 14/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.1125 - categorical_accuracy: 0.9610
# Epoch 14: val_categorical_accuracy improved from 0.66667 to 0.71087, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_10/training_weights.h5
# 247/247 [==============================] - 16s 66ms/step - loss: 0.1123 - categorical_accuracy: 0.9611 - val_loss: 1.8834 - val_categorical_accuracy: 0.7109 - lr: 0.0010
# Epoch 15/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0902 - categorical_accuracy: 0.9675
# Epoch 15: val_categorical_accuracy did not improve from 0.71087
# 247/247 [==============================] - 15s 61ms/step - loss: 0.0900 - categorical_accuracy: 0.9676 - val_loss: 3.2371 - val_categorical_accuracy: 0.5818 - lr: 0.0010
# Epoch 16/50
# 247/247 [==============================] - ETA: 0s - loss: 0.0891 - categorical_accuracy: 0.9692
# Epoch 16: val_categorical_accuracy did not improve from 0.71087
# 247/247 [==============================] - 15s 62ms/step - loss: 0.0891 - categorical_accuracy: 0.9692 - val_loss: 2.0039 - val_categorical_accuracy: 0.6177 - lr: 0.0010
# Epoch 17/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0679 - categorical_accuracy: 0.9760
# Epoch 17: val_categorical_accuracy did not improve from 0.71087
# 247/247 [==============================] - 15s 61ms/step - loss: 0.0677 - categorical_accuracy: 0.9761 - val_loss: 7.1928 - val_categorical_accuracy: 0.3489 - lr: 0.0010
# Epoch 18/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0434 - categorical_accuracy: 0.9849
# Epoch 18: val_categorical_accuracy did not improve from 0.71087
# 247/247 [==============================] - 15s 61ms/step - loss: 0.0433 - categorical_accuracy: 0.9849 - val_loss: 2.6658 - val_categorical_accuracy: 0.6858 - lr: 0.0010
# Epoch 19/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0581 - categorical_accuracy: 0.9809
# Epoch 19: val_categorical_accuracy did not improve from 0.71087
# 247/247 [==============================] - 15s 61ms/step - loss: 0.0582 - categorical_accuracy: 0.9809 - val_loss: 1.6570 - val_categorical_accuracy: 0.6738 - lr: 0.0010
# Epoch 20/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0857 - categorical_accuracy: 0.9701
# Epoch 20: val_categorical_accuracy did not improve from 0.71087
# 247/247 [==============================] - 15s 61ms/step - loss: 0.0858 - categorical_accuracy: 0.9701 - val_loss: 1.9935 - val_categorical_accuracy: 0.6846 - lr: 0.0010
# Epoch 21/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0636 - categorical_accuracy: 0.9793
# Epoch 21: val_categorical_accuracy did not improve from 0.71087
# 247/247 [==============================] - 15s 61ms/step - loss: 0.0634 - categorical_accuracy: 0.9794 - val_loss: 2.5721 - val_categorical_accuracy: 0.6177 - lr: 0.0010
# Epoch 22/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0454 - categorical_accuracy: 0.9835
# Epoch 22: val_categorical_accuracy did not improve from 0.71087
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 247/247 [==============================] - 15s 61ms/step - loss: 0.0454 - categorical_accuracy: 0.9835 - val_loss: 1.7593 - val_categorical_accuracy: 0.7037 - lr: 0.0010
# Epoch 23/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0182 - categorical_accuracy: 0.9943
# Epoch 23: val_categorical_accuracy improved from 0.71087 to 0.72043, saving model to /content/drive/MyDrive/UrbanSound Classification - Domaci/Mel/fold_10/training_weights.h5
# 247/247 [==============================] - 16s 66ms/step - loss: 0.0182 - categorical_accuracy: 0.9943 - val_loss: 1.4120 - val_categorical_accuracy: 0.7204 - lr: 1.0000e-04
# Epoch 24/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0102 - categorical_accuracy: 0.9966
# Epoch 24: val_categorical_accuracy did not improve from 0.72043
# 247/247 [==============================] - 15s 61ms/step - loss: 0.0102 - categorical_accuracy: 0.9966 - val_loss: 1.3795 - val_categorical_accuracy: 0.7097 - lr: 1.0000e-04
# Epoch 25/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0093 - categorical_accuracy: 0.9970
# Epoch 25: val_categorical_accuracy did not improve from 0.72043
# 247/247 [==============================] - 15s 60ms/step - loss: 0.0093 - categorical_accuracy: 0.9970 - val_loss: 1.3721 - val_categorical_accuracy: 0.7085 - lr: 1.0000e-04
# Epoch 26/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0081 - categorical_accuracy: 0.9971
# Epoch 26: val_categorical_accuracy did not improve from 0.72043
# 247/247 [==============================] - 15s 60ms/step - loss: 0.0081 - categorical_accuracy: 0.9971 - val_loss: 1.4592 - val_categorical_accuracy: 0.6870 - lr: 1.0000e-04
# Epoch 27/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0070 - categorical_accuracy: 0.9975
# Epoch 27: val_categorical_accuracy did not improve from 0.72043
# 247/247 [==============================] - 15s 61ms/step - loss: 0.0070 - categorical_accuracy: 0.9975 - val_loss: 1.4565 - val_categorical_accuracy: 0.6918 - lr: 1.0000e-04
# Epoch 28/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0066 - categorical_accuracy: 0.9976
# Epoch 28: val_categorical_accuracy did not improve from 0.72043
# 247/247 [==============================] - 15s 62ms/step - loss: 0.0066 - categorical_accuracy: 0.9976 - val_loss: 1.4809 - val_categorical_accuracy: 0.6977 - lr: 1.0000e-04
# Epoch 29/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0070 - categorical_accuracy: 0.9972
# Epoch 29: val_categorical_accuracy did not improve from 0.72043
# 247/247 [==============================] - 15s 62ms/step - loss: 0.0070 - categorical_accuracy: 0.9972 - val_loss: 1.4893 - val_categorical_accuracy: 0.6846 - lr: 1.0000e-04
# Epoch 30/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0057 - categorical_accuracy: 0.9982
# Epoch 30: val_categorical_accuracy did not improve from 0.72043
# 247/247 [==============================] - 15s 62ms/step - loss: 0.0057 - categorical_accuracy: 0.9982 - val_loss: 1.5540 - val_categorical_accuracy: 0.6858 - lr: 1.0000e-04
# Epoch 31/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0058 - categorical_accuracy: 0.9978
# Epoch 31: val_categorical_accuracy did not improve from 0.72043
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 247/247 [==============================] - 15s 62ms/step - loss: 0.0058 - categorical_accuracy: 0.9978 - val_loss: 1.5095 - val_categorical_accuracy: 0.6989 - lr: 1.0000e-04
# Epoch 32/50
# 247/247 [==============================] - ETA: 0s - loss: 0.0055 - categorical_accuracy: 0.9973
# Epoch 32: val_categorical_accuracy did not improve from 0.72043
# 247/247 [==============================] - 15s 62ms/step - loss: 0.0055 - categorical_accuracy: 0.9973 - val_loss: 1.5327 - val_categorical_accuracy: 0.6858 - lr: 1.0000e-05
# Epoch 33/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0055 - categorical_accuracy: 0.9978
# Epoch 33: val_categorical_accuracy did not improve from 0.72043
# 247/247 [==============================] - 15s 62ms/step - loss: 0.0056 - categorical_accuracy: 0.9978 - val_loss: 1.5410 - val_categorical_accuracy: 0.6834 - lr: 1.0000e-05
# Epoch 34/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0051 - categorical_accuracy: 0.9982
# Epoch 34: val_categorical_accuracy did not improve from 0.72043
# 247/247 [==============================] - 15s 61ms/step - loss: 0.0051 - categorical_accuracy: 0.9982 - val_loss: 1.5283 - val_categorical_accuracy: 0.6882 - lr: 1.0000e-05
# Epoch 35/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0054 - categorical_accuracy: 0.9978
# Epoch 35: val_categorical_accuracy did not improve from 0.72043
# 247/247 [==============================] - 15s 62ms/step - loss: 0.0054 - categorical_accuracy: 0.9978 - val_loss: 1.5213 - val_categorical_accuracy: 0.6906 - lr: 1.0000e-05
# Epoch 36/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0051 - categorical_accuracy: 0.9983
# Epoch 36: val_categorical_accuracy did not improve from 0.72043
# 247/247 [==============================] - 15s 61ms/step - loss: 0.0051 - categorical_accuracy: 0.9984 - val_loss: 1.5337 - val_categorical_accuracy: 0.6894 - lr: 1.0000e-05
# Epoch 37/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0049 - categorical_accuracy: 0.9982
# Epoch 37: val_categorical_accuracy did not improve from 0.72043
# 247/247 [==============================] - 15s 61ms/step - loss: 0.0050 - categorical_accuracy: 0.9982 - val_loss: 1.5311 - val_categorical_accuracy: 0.6906 - lr: 1.0000e-05
# Epoch 38/50
# 246/247 [============================>.] - ETA: 0s - loss: 0.0050 - categorical_accuracy: 0.9982
# Epoch 38: val_categorical_accuracy did not improve from 0.72043
# Restoring model weights from the end of the best epoch: 23.
# 247/247 [==============================] - 15s 61ms/step - loss: 0.0050 - categorical_accuracy: 0.9982 - val_loss: 1.5292 - val_categorical_accuracy: 0.6918 - lr: 1.0000e-05
# Epoch 38: early stopping
# Score for fold 10: loss of 1.4120230674743652; categorical_accuracy of 72.04301357269287%

# %% [markdown]
# Grafici:

# %%
for i in range(0,10):
    _ = plt.figure(figsize=(6,4))
    _ = plt.title('Accuracy for Fold '+str(i+1))
    _ = plt.plot(histories[i].history['accuracy'], label='train')
    _ = plt.plot(histories[i].history['val_accuracy'], label='test')
    _ = plt.legend()
    plt.show()

for i in range(0,10):
    _ = plt.figure(figsize=(6,4))
    _ = plt.title('Loss for Fold '+str(i+1))
    _ = plt.plot(histories[i].history['loss'], label='train')
    _ = plt.plot(histories[i].history['val_loss'], label='test')
    _ = plt.legend()
    plt.show()

# %% [markdown]
# Evaluacija:

# %%
final_score=np.mean(acc_per_fold)
np.mean(acc_per_fold)
# Out:
# 71.23448967933655
